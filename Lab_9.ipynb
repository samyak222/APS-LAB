# %% [markdown]
# <a href="https://colab.research.google.com/github/samyak222/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    dist = {node: float('inf') for node in graph}
    prev = {}
    visited = []

    dist[start] = 0

    while len(visited) < len(graph):
        min_node = None
        for node in graph:
            if node not in visited and (min_node is None or dist[node] < dist[min_node]):
                min_node = node

        visited.append(min_node)

        for neighbor in graph[min_node]:
            new_dist = dist[min_node] + graph[min_node][neighbor]
            if new_dist < dist[neighbor]:
                dist[neighbor] = new_dist
                prev[neighbor] = min_node

    return dist, prev


def path(prev, start, end):
    p = []
    while end != start:
        p.append(end)
        end = prev.get(end)
    p.append(start)
    return p[::-1]

# %%
graph = {}
n = int(input("Nodes: "))

for _ in range(n):
    node = input("Node: ")
    graph[node] = {}
    e = int(input("Edges: "))
    for _ in range(e):
        nb = input("Neighbor: ")
        w = int(input("Weight: "))
        graph[node][nb] = w

for _ in range(2):
    node = input("Extra Node: ")
    graph[node] = {}
    e = int(input("Edges: "))
    for _ in range(e):
        nb = input("Neighbor: ")
        w = int(input("Weight: "))
        graph[node][nb] = w


while True:
    start = input("\nSource (exit to stop): ")
    if start == "exit":
        break

    dist, prev = dijkstra(graph, start)

    for node in graph:
        print(start, "->", node, "=", dist[node],
              "| Path:", "->".join(path(prev, start, node)))
# Out:
# Nodes: 2
# Node: 1
# Edges: 1
# Neighbor: 2
# Weight: 3
# Node: 2
# Edges: 1
# Neighbor: 1
# Weight: 3
# Extra Node: 0
# Edges: 0
# Extra Node: 0
# Edges: 0
#
# Source (exit to stop): 2
# 2 -> 1 = 3 | Path: 2->1
# 2 -> 2 = 0 | Path: 2

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
