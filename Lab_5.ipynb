# %% [markdown]
# <a href="https://colab.research.google.com/github/samyak222/APS-LAB/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt

def selection_sort(numbers):
    n = len(numbers)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if numbers[j] < numbers[min_index]:
                min_index = j
        numbers[i], numbers[min_index] = numbers[min_index], numbers[i]


n = int(input("Enter number of elements: "))

numbers = []

for i in range(n):
    element = int(input(f"Enter element {i+1}: "))
    numbers.append(element)

print("\nOriginal List:", numbers)


start_time = time.time()
selection_sort(numbers)
end_time = time.time()

running_time = (end_time - start_time) * 1000


print("Sorted List:", numbers)
print(f"Running Time: {running_time:.4f} ms")

sizes = [10, 50, 100, 200, 500]
times = []

for size in sizes:
    test_list = list(range(size, 0, -1))
    start = time.time()
    selection_sort(test_list)
    end = time.time()
    times.append((end - start) * 1000)
32
plt.plot(sizes, times, marker='o')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time (ms)")
plt.title("Selection Sort Time Complexity")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 20
# Enter element 1: 230
# Enter element 2: 264
# Enter element 3: 256
# Enter element 4: 562
# Enter element 5: 456
# Enter element 6: 956
# Enter element 7: 652
# Enter element 8: 26
# Enter element 9: 156
# Enter element 10: 423
# Enter element 11: 515
# Enter element 12: 879
# Enter element 13: 515
# Enter element 14: 789
# Enter element 15: 156
# Enter element 16: 489
# Enter element 17: 500
# Enter element 18: 400
# Enter element 19: 900
# Enter element 20: 1500
#
# Original List: [230, 264, 256, 562, 456, 956, 652, 26, 156, 423, 515, 879, 515, 789, 156, 489, 500, 400, 900, 1500]
# Sorted List: [26, 156, 156, 230, 256, 264, 400, 423, 456, 489, 500, 515, 515, 562, 652, 789, 879, 900, 956, 1500]
# Running Time: 0.0970 ms

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt


def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)


def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

n_values = [100, 200, 400, 800, 1600, 3200, 6400]
time_taken = []


for n in n_values:
    arr = [random.randint(1, 100000) for _ in range(n)]
    start = time.perf_counter()
    merge_sort(arr)
    end = time.perf_counter()
    time_taken.append(end - start)


plt.plot(n_values, time_taken, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Merge Sort Time Complexity (Divide and Conquer)")
plt.show()

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        less = [x for x in arr[1:] if x <= pivot]
        middle = [x for x in arr[1:] if x == pivot]
        greater = [x for x in arr[1:] if x > pivot]
        return quick_sort(less) + middle + quick_sort(greater)

n_values = [100, 200, 400, 800, 1600,2000,6400]
time_taken = []

for n in n_values:
    arr = [random.randint(1, 100000) for _ in range(n)]
    start = time.perf_counter()
    quick_sort(arr)
    end = time.perf_counter()
    time_taken.append(end - start)

plt.plot(n_values, time_taken, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Quick Sort Time Complexity (Divide and Conquer)")
plt.show()

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
import random
import matplotlib.pyplot as plt
import datetime
import timeit
import copy
import numpy as np

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
selection_limit = 10000  # selection sort cutoff

n_max = n_list[-1]

ms = datetime.datetime.now().microsecond / 1000
random.seed(int(ms))

numbers = [random.randint(0, 1000) for _ in range(n_max)]

quick_times = []
merge_times = []
selection_times = []

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]


def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)


def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)


def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

# %%
# Creating a random value (uniform)
for n in n_list:
    print(f"Running for n = {n}")

    a = copy.deepcopy(numbers[:n])
    b = copy.deepcopy(numbers[:n])

    start = timeit.default_timer()
    quick_sort(a)
    quick_times.append((timeit.default_timer() - start) * 1000)

    start = timeit.default_timer()
    merge_sort(b)
    merge_times.append((timeit.default_timer() - start) * 1000)

    if n <= selection_limit:
        c = copy.deepcopy(numbers[:n])
        start = timeit.default_timer()
        selection_sort(c)
        selection_times.append((timeit.default_timer() - start) * 1000)
    else:
        selection_times.append(None)
# Out:
# Running for n = 1000
# Running for n = 2000
# Running for n = 5000
# Running for n = 10000
# Running for n = 20000
# Running for n = 50000
# Running for n = 100000
# Running for n = 200000

# %%
# Plotting results
plt.figure(figsize=(10, 5))

plt.plot(n_list, quick_times, marker="o", label="Quicksort")
plt.plot(n_list, merge_times, marker="o", label="Mergesort")

sel_n = [n for n, t in zip(n_list, selection_times) if t is not None]
sel_t = [t for t in selection_times if t is not None]
plt.plot(sel_n, sel_t, marker="o", label="Selection sort")

plt.yscale("log")
plt.xlabel("n")
plt.ylabel("Time (ms)")
plt.title("Comparison of Sorting Algorithms")
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)

plt.show()
